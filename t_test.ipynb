# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# Load Titanic dataset
data = sns.load_dataset('titanic')

# Display the first few rows of the dataset
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Drop rows with missing 'age' values for simplicity in hypothesis testing
data_cleaned = data.dropna(subset=['age'])

# Display the dataset after cleaning
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     714 non-null    int64
#  1   pclass       714 non-null    int64
#  2   sex          714 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        714 non-null    int64
#  5   parch        714 non-null    int64
#  6   fare         714 non-null    float64
#  7   embarked     712 non-null    object
#  8   class        714 non-null    category
#  9   who          714 non-null    object
#  10  adult_male   714 non-null    bool
#  11  deck         184 non-null    category
#  12  embark_town  712 non-null    object
#  13  alive        714 non-null    object
#  14  alone        714 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 70.2+ KB

# %%
# Visualize the distribution of ages for male and female passengers
plt.figure(figsize=(10,6))
sns.histplot(data=data_cleaned, x='age', hue='sex', kde=True)
plt.title('Age Distribution by Gender')
plt.show()

# %%
# Split the data into two groups: male and female
male_age = data_cleaned[data_cleaned['sex'] == 'male']['age']
female_age = data_cleaned[data_cleaned['sex'] == 'female']['age']

# Perform an independent t-test
t_stat, p_value = stats.ttest_ind(male_age, female_age)

# Output the t-statistic and p-value
t_stat, p_value
# Out:
# (2.499206354920835, 0.012671296797013709)

# %%
# Significance level (alpha)
alpha = 0.05

# Interpretation of hypothesis test result
if p_value < alpha:
    print(f"The p-value ({p_value}) is less than the significance level ({alpha}).")
    print("We reject the null hypothesis. There is a significant difference between the average ages of male and female passengers.")
else:
    print(f"The p-value ({p_value}) is greater than the significance level ({alpha}).")
    print("We fail to reject the null hypothesis. There is no significant difference between the average ages of male and female passengers.")
# Out:
# The p-value (0.012671296797013709) is less than the significance level (0.05).
# We reject the null hypothesis. There is a significant difference between the average ages of male and female passengers.
